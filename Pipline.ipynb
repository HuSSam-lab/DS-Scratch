# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

x=datasets.load_iris()
X=x.data
Y=x.target

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25)

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
pipe=Pipeline([])

pipe.fit(X_train,Y_train)
print
# Out:
# [Pipeline] ............... (step 1 of 3) Processing pca, total=   0.0s
# [Pipeline] ............... (step 2 of 3) Processing std, total=   0.0s
# [Pipeline] ..... (step 3 of 3) Processing decision_tree, total=   0.0s
# ...

# %%
import pandas as pd
data = pd.read_csv("C:/Users/hussam/Desktop/Catogorical_Columns/melb_data.csv")
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  \
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN  \
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

numerical_transformer = SimpleImputer(strategy='constant')

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  ...  CouncilArea_Yarra
# 0         202.0           NaN        NaN  ...               True  \
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=1480000, strategy="most_frequent")
imputer.fit(pd.array(data['Price']).reshape(-1,1))

d = imputer.transform(pd.array(data['Price']).reshape(-1, 1))
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\hussam\Desktop\Pipline.ipynb Cell 6 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/Pipline.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.impute import SimpleImputer
#       <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/Pipline.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> imputer = SimpleImputer(missing_values=1480000, strategy="most_frequent")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/Pipline.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> imputer.fit(pd.array(data['Price']).reshape(-1,1))
#       <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/Pipline.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> d = imputer.transform(pd.array(data['Price']).reshape(-1, 1))
#       <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/Pipline.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> print(d)
#
# ...

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import Normalizer

ct=ColumnTransformer(
    [('norm1',Normalizer(norm="l1"),[0,1,2,3]),
     ('norm2', Normalizer(norm="max"), [0, 1, 2, 3])]
)
X=np.array([[0,1,2,2],[1,1,0,1]])
print(X)
ct.fit_transform(X)
# Out:
# [[0 1 2 2]
#  [1 1 0 1]]
# array([[0.        , 0.2       , 0.4       , 0.4       , 0.        ,
#         0.5       , 1.        , 1.        ],
#        [0.33333333, 0.33333333, 0.        , 0.33333333, 1.        ,
#         1.        , 0.        , 1.        ]])

# %%
ll='abdbababa'
ll=pd.get_dummies(pd.Series(list(ll)))
print(ll)
# Out:
#        a      b      d
# 0   True  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False   True  False
# 4   True  False  False
# 5  False   True  False
# 6   True  False  False
# 7  False   True  False
# 8   True  False  False

# %% [markdown]
# ### pipeline Scratch

# %%
from xgboost import
