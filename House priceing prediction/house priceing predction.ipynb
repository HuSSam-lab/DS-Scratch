# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("train.csv")
data = data.drop(['Alley', 'PoolQC', 'Fence', 'MiscFeature'], axis=1)
t_data=data

# %%
t_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl  \
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea
# 0    AllPub    Inside  ...             0         0           0        0  \
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
t_nul_col_with_number_of_misssing=[t_data[i].isnull().sum() for i in t_data.columns if t_data[i].isnull().any()]
t_nul_col_with_name = [i for i in t_data.columns if t_data[i].isnull().any()]
print(
    f"thier are {len(t_nul_col_with_number_of_misssing)} columns with missing values")
for i in range(len(t_nul_col_with_name)):

    print(f"{t_nul_col_with_number_of_misssing[i],t_nul_col_with_name[i]}")
# Out:
# thier are 15 columns with missing values
# (259, 'LotFrontage')
# (872, 'MasVnrType')
# (8, 'MasVnrArea')
# (37, 'BsmtQual')
# (37, 'BsmtCond')
# (38, 'BsmtExposure')
# (37, 'BsmtFinType1')
# (38, 'BsmtFinType2')
# (1, 'Electrical')
# (690, 'FireplaceQu')
# (81, 'GarageType')
# (81, 'GarageYrBlt')
# (81, 'GarageFinish')
# (81, 'GarageQual')
# (81, 'GarageCond')

# %% [markdown]
# here we while drop the columns which have more than 1000 nun values from the data set

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.impute import SimpleImputer


my_imputer = SimpleImputer( strategy='most_frequent')
imputed_t_data=pd.DataFrame(my_imputer.fit_transform(t_data,type))
imputed_t_data.columns=t_data.columns

imputed_t_data = imputed_t_data.astype(t_data.dtypes.to_dict())
d=[i for i in imputed_t_data.columns if imputed_t_data[i].isnull().any()]
print(
    f"thier are {len(d)} columns with missing values")

imputed_t_data.info()
# Out:
# thier are 0 columns with missing values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
# ...

# %%
imputed_t_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl  \
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea
# 0    AllPub    Inside  ...             0         0           0        0  \
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# num_col = [
#     col for col in imputed_t_data.columns if imputed_t_data[col].dtype == ("float64" or "int64")]
# cat_col=[i for i in imputed_t_data.select_dtypes(exclude=['object'])]

import pandas as pd
num_col_t=imputed_t_data.select_dtypes(include=("int64","float64")).columns
cat_col_t=imputed_t_data.select_dtypes(include=("object")).columns



# # imputed_t_data[cat_col] = pd.get_dummies(imputed_t_data[cat_col])
# from sklearn.preprocessing import OneHotEncoder
# onh=OneHotEncoder()

# OH_encoder = OneHotEncoder(handle_unknown='ignore')

# OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(imputed_t_data[cat_col]))

# # One-hot encoding removed index; put it back
# OH_cols_train.index = imputed_t_data.index

# # Remove categorical columns (will replace with one-hot encoding)
# num_X_train = imputed_t_data.drop(cat_col, axis=1)

# # Add one-hot encoded columns to numerical features
# oh_imputed_t_data = pd.concat([num_X_train, OH_cols_train], axis=1)

# print(cat_col)

# print(oh_imputed_t_data.columns)
# object_nunique = list(map(lambda col: imputed_t_data[col].nunique(), cat_col))
# d = dict(zip(cat_col, object_nunique))
# print(d)

cat_temp_data=pd.get_dummies(imputed_t_data[cat_col_t])

num_temp_data=imputed_t_data[num_col_t]
f_data = pd.concat([cat_temp_data, num_temp_data],axis=1)

# f_data = pd.DataFrame(f_data,columns=[cat_temp_data.columns, num_temp_data.columns])
f_data.to_csv('ggg.csv')

# %%
from sklearn.model_selection import train_test_split
data = f_data
X_train,X_valid=train_test_split(data)
y_train = X_train.drop(['SalePrice'],axis=1)
y_valid = X_valid.drop(['SalePrice'],axis=1)

# %%
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor

model1 = XGBRegressor(n_estimators=500,learning_rate=0.01)
model1.fit(X_train, y_train)
predictions = model1.predict(X_valid)

mse = mean_squared_error(y_valid, predictions)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\hussam\Desktop\keggel folder\House priceing prediction\house priceing predction.ipynb Cell 11 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/keggel%20folder/House%20priceing%20prediction/house%20priceing%20predction.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> from xgboost import XGBRegressor
#       <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/keggel%20folder/House%20priceing%20prediction/house%20priceing%20predction.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> my_model = XGBRegressor(n_estimators=500,learning_rate=0.01)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hussam/Desktop/keggel%20folder/House%20priceing%20prediction/house%20priceing%20predction.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> my_model.fit(X_train, y_train)
# ...

# %%
# Out:
# 77713.5039330125

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor(n_estimators=50, random_state=0)
model2.fit(X_train, y_train)
predictions = model2.predict(X_valid)

mse = mean_squared_error(y_valid, predictions)
print(mse)
